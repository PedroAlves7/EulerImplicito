# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroAlves7/EulerImplicito/blob/main/EulerImplicito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from math import e
import matplotlib.pyplot as plt

t = 0
tf = 0.3
h = 0.1
n = round((tf - t)/h)
u = 2

def aproximada(u,t):
  valores = []
  for i in range(n):
    t = t + h
    u = (u + h*(t + 2))/(1 + h)
    valores.append(u)
  return valores

print(aproximada(u,t))

def exata(t):
  return t + 1 +(1/e**t)

print(exata(tf))

# Lista da solução aproximada
valores_aproximados = aproximada(u, t)

# Lista da solução exata
valores_exatos = []
for i in range(n):
  valores_exatos.append(exata(tf))

# Plotagem dos gráficos
iteracoes = np.linspace(t, tf, n, endpoint=False)
plt.plot(iteracoes, valores_aproximados, 'r-', label='Solução Aproximada')
plt.plot(iteracoes, valores_exatos, 'b-', label='Solução Exata')
plt.legend()
plt.xlabel('Iteraçoes')
plt.ylabel('Valor de u')
plt.title('Comparação entre Solução Aproximada e Exata')
plt.show()
# Out:
# [2.009090909090909, 2.026446280991735, 2.051314800901577]
# 2.040818220681718
